# %%
import Pkg;
Pkg.add("StatsPlots")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed Distances ───────── v0.10.7
#    Installed IntelOpenMP_jll ─── v2018.0.3+2
#    Installed Ratios ──────────── v0.4.2
#    Installed FFTW ────────────── v1.4.6
#    Installed OffsetArrays ────── v1.10.8
#    Installed StatsPlots ──────── v0.14.33
#    Installed NearestNeighbors ── v0.4.9
#    Installed DataValues ──────── v0.4.13
#    Installed MKL_jll ─────────── v2022.0.0+0
#    Installed KernelDensity ───── v0.6.3
#    Installed FFTW_jll ────────── v3.3.10+0
#    Installed AbstractFFTs ────── v1.1.0
#    Installed Widgets ─────────── v0.6.5
#    Installed MultivariateStats ─ v0.9.0
#    Installed Clustering ──────── v0.14.2
#    Installed Arpack_jll ──────── v3.5.1+1
#    Installed AxisAlgorithms ──── v1.0.1
#    Installed TableOperations ─── v1.2.0
#    Installed Arpack ──────────── v0.5.3
#    Installed WoodburyMatrices ── v0.5.5
#    Installed Observables ─────── v0.4.0
#    Installed Interpolations ──── v0.13.5
#     Updating `~/.julia/environments/v1.7/Project.toml`
#   [f3b207a7] + StatsPlots v0.14.33
#     Updating `~/.julia/environments/v1.7/Manifest.toml`
#   [621f4979] + AbstractFFTs v1.1.0
#   [7d9fca2a] + Arpack v0.5.3
#   [13072b0f] + AxisAlgorithms v1.0.1
#   [aaaa29a8] + Clustering v0.14.2
#   [e7dc6d0d] + DataValues v0.4.13
#   [b4f34e82] + Distances v0.10.7
#   [7a1cc6ca] + FFTW v1.4.6
#   [a98d9a8b] + Interpolations v0.13.5
#   [5ab0869b] + KernelDensity v0.6.3
#   [6f286f6a] + MultivariateStats v0.9.0
#   [b8a86587] + NearestNeighbors v0.4.9
#   [510215fc] + Observables v0.4.0
#   [6fe1bfb0] + OffsetArrays v1.10.8
#   [c84ed2f1] + Ratios v0.4.2
#   [f3b207a7] + StatsPlots v0.14.33
#   [ab02a1b2] + TableOperations v1.2.0
#   [cc8bc4a8] + Widgets v0.6.5
#   [efce3f68] + WoodburyMatrices v0.5.5
#   [68821587] + Arpack_jll v3.5.1+1
#   [f5851436] + FFTW_jll v3.3.10+0
#   [1d5cc7b8] + IntelOpenMP_jll v2018.0.3+2
#   [856f044c] + MKL_jll v2022.0.0+0
#   [4af54fe1] + LazyArtifacts
# Precompiling project...
#   ✓ WoodburyMatrices
#   ✓ Ratios
#   ✓ Observables
#   ✓ AbstractFFTs
#   ✓ Distances
#   ✓ IntelOpenMP_jll
#   ✓ DataValues
#   ✓ AxisAlgorithms
#   ✓ Arpack_jll
#   ✓ OffsetArrays
#   ✓ FFTW_jll
#   ✓ TableOperations
#   ✓ MKL_jll
#   ✓ Widgets
#   ✓ Arpack
#   ✓ NearestNeighbors
#   ✓ MultivariateStats
#   ✓ Interpolations
#   ✓ Clustering
#   ✓ FFTW
#   ✓ KernelDensity
#   ✓ StatsPlots
#   22 dependencies successfully precompiled in 18 seconds (165 already precompiled)

# %%
using CSV
using CategoricalArrays
using Chain
using DataFrames
using GLM
using Plots
using Random
using StatsPlots
using Statistics
using Dates

# %%
# Step 1: Specify the file location
URL = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"

# Step 2: Specify the path
path = joinpath(pwd(), "confirmed.csv")

# Step 3: Download the file
download(URL, path)

# Step 4: Reading the CSV file into a DataFrame
df = CSV.File(path) |> DataFrame
# Out:
# 284×776 DataFrame
#  Row │ Province/State                     Country/Region        Lat       Long ⋯
#      │ String?                            String                Float64?  Floa ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ missing                            Afghanistan            33.9391   67. ⋯
#    2 │ missing                            Albania                41.1533   20.
#    3 │ missing                            Algeria                28.0339    1.
#    4 │ missing                            Andorra                42.5063    1.
#    5 │ missing                            Angola                -11.2027   17. ⋯
#    6 │ missing                            Antarctica            -71.9499   23.
#    7 │ missing                            Antigua and Barbuda    17.0608  -61.
#    8 │ missing                            Argentina             -38.4161  -63.
#    9 │ missing                            Armenia                40.0691   45. ⋯
#   10 │ Australian Capital Territory       Australia             -35.4735  149.
#   11 │ New South Wales                    Australia             -33.8688  151.
#   ⋮  │                 ⋮                           ⋮               ⋮         ⋮ ⋱
#  275 │ missing                            Uruguay               -32.5228  -55.
#  276 │ missing                            Uzbekistan             41.3775   64. ⋯
#  277 │ missing                            Vanuatu               -15.3767  166.
#  278 │ missing                            Venezuela               6.4238  -66.
#  279 │ missing                            Vietnam                14.0583  108.
#  280 │ missing                            West Bank and Gaza     31.9522   35. ⋯
#  281 │ missing                            Winter Olympics 2022   39.9042  116.
#  282 │ missing                            Yemen                  15.5527   48.
#  283 │ missing                            Zambia                -13.1339   27.
#  284 │ missing                            Zimbabwe              -19.0154   29. ⋯
#                                                 773 columns and 263 rows omitted

# %%
#Tidying Data

select!(df, Not(["Province/State", "Lat", "Long"]))
# Out:
# 284×773 DataFrame
#  Row │ Country/Region        1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27 ⋯
#      │ String                Int64    Int64    Int64    Int64    Int64    Int6 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Afghanistan                 0        0        0        0        0       ⋯
#    2 │ Albania                     0        0        0        0        0
#    3 │ Algeria                     0        0        0        0        0
#    4 │ Andorra                     0        0        0        0        0
#    5 │ Angola                      0        0        0        0        0       ⋯
#    6 │ Antarctica                  0        0        0        0        0
#    7 │ Antigua and Barbuda         0        0        0        0        0
#    8 │ Argentina                   0        0        0        0        0
#    9 │ Armenia                     0        0        0        0        0       ⋯
#   10 │ Australia                   0        0        0        0        0
#   11 │ Australia                   0        0        0        0        3
#   ⋮  │          ⋮               ⋮        ⋮        ⋮        ⋮        ⋮        ⋮ ⋱
#  275 │ Uruguay                     0        0        0        0        0
#  276 │ Uzbekistan                  0        0        0        0        0       ⋯
#  277 │ Vanuatu                     0        0        0        0        0
#  278 │ Venezuela                   0        0        0        0        0
#  279 │ Vietnam                     0        2        2        2        2
#  280 │ West Bank and Gaza          0        0        0        0        0       ⋯
#  281 │ Winter Olympics 2022        0        0        0        0        0
#  282 │ Yemen                       0        0        0        0        0
#  283 │ Zambia                      0        0        0        0        0
#  284 │ Zimbabwe                    0        0        0        0        0       ⋯
#                                                 767 columns and 263 rows omitted

# %%
#Removing duplicates
grp = groupby(df, "Country/Region") 
column_names = names(grp)
date_columns = column_names[2:end] # select all columns except the first column "Country/Region"
df = combine(grp, date_columns .=> sum .=> date_columns)
# Out:
# 198×773 DataFrame
#  Row │ Country/Region        1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27 ⋯
#      │ String                Int64    Int64    Int64    Int64    Int64    Int6 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Afghanistan                 0        0        0        0        0       ⋯
#    2 │ Albania                     0        0        0        0        0
#    3 │ Algeria                     0        0        0        0        0
#    4 │ Andorra                     0        0        0        0        0
#    5 │ Angola                      0        0        0        0        0       ⋯
#    6 │ Antarctica                  0        0        0        0        0
#    7 │ Antigua and Barbuda         0        0        0        0        0
#    8 │ Argentina                   0        0        0        0        0
#    9 │ Armenia                     0        0        0        0        0       ⋯
#   10 │ Australia                   0        0        0        0        4
#   11 │ Austria                     0        0        0        0        0
#   ⋮  │          ⋮               ⋮        ⋮        ⋮        ⋮        ⋮        ⋮ ⋱
#  189 │ Uruguay                     0        0        0        0        0
#  190 │ Uzbekistan                  0        0        0        0        0       ⋯
#  191 │ Vanuatu                     0        0        0        0        0
#  192 │ Venezuela                   0        0        0        0        0
#  193 │ Vietnam                     0        2        2        2        2
#  194 │ West Bank and Gaza          0        0        0        0        0       ⋯
#  195 │ Winter Olympics 2022        0        0        0        0        0
#  196 │ Yemen                       0        0        0        0        0
#  197 │ Zambia                      0        0        0        0        0
#  198 │ Zimbabwe                    0        0        0        0        0       ⋯
#                                                 767 columns and 177 rows omitted

# %%
first(df,10)
# Out:
# 10×773 DataFrame
#  Row │ Country/Region       1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/ ⋯
#      │ String               Int64    Int64    Int64    Int64    Int64    Int64 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Afghanistan                0        0        0        0        0        ⋯
#    2 │ Albania                    0        0        0        0        0
#    3 │ Algeria                    0        0        0        0        0
#    4 │ Andorra                    0        0        0        0        0
#    5 │ Angola                     0        0        0        0        0        ⋯
#    6 │ Antarctica                 0        0        0        0        0
#    7 │ Antigua and Barbuda        0        0        0        0        0
#    8 │ Argentina                  0        0        0        0        0
#    9 │ Armenia                    0        0        0        0        0        ⋯
#   10 │ Australia                  0        0        0        0        4
#                                                              767 columns omitted

# %%
#Creating 1 column dates & 1 column Cases

df = DataFrames.stack(
    df,
    Not("Country/Region"),
    "Country/Region",
    variable_name="Date",
    value_name="Cases",
)
# Out:
# 152856×3 DataFrame
#     Row │ Country/Region        Date     Cases
#         │ String                String   Int64
# ────────┼─────────────────────────────────────────
#       1 │ Afghanistan           1/22/20         0
#       2 │ Albania               1/22/20         0
#       3 │ Algeria               1/22/20         0
#       4 │ Andorra               1/22/20         0
#       5 │ Angola                1/22/20         0
#       6 │ Antarctica            1/22/20         0
#       7 │ Antigua and Barbuda   1/22/20         0
#       8 │ Argentina             1/22/20         0
#       9 │ Armenia               1/22/20         0
#      10 │ Australia             1/22/20         0
#      11 │ Austria               1/22/20         0
#    ⋮    │          ⋮               ⋮        ⋮
#  152847 │ Uruguay               3/3/22     849050
#  152848 │ Uzbekistan            3/3/22     236687
#  152849 │ Vanuatu               3/3/22         19
#  152850 │ Venezuela             3/3/22     515943
#  152851 │ Vietnam               3/3/22    3885631
#  152852 │ West Bank and Gaza    3/3/22     649110
#  152853 │ Winter Olympics 2022  3/3/22        526
#  152854 │ Yemen                 3/3/22      11772
#  152855 │ Zambia                3/3/22     313394
#  152856 │ Zimbabwe              3/3/22     237503
#                                152835 rows omitted

# %%
last(df, 20)
# Out:
# 20×3 DataFrame
#  Row │ Country/Region        Date    Cases
#      │ String                String  Int64
# ─────┼────────────────────────────────────────
#    1 │ Togo                  3/3/22     36812
#    2 │ Tonga                 3/3/22       645
#    3 │ Trinidad and Tobago   3/3/22    128976
#    4 │ Tunisia               3/3/22   1000518
#    5 │ Turkey                3/3/22  14255545
#    6 │ US                    3/3/22  79196008
#    7 │ Uganda                3/3/22    163383
#    8 │ Ukraine               3/3/22   5040518
#    9 │ United Arab Emirates  3/3/22    881472
#   10 │ United Kingdom        3/3/22  19211944
#   11 │ Uruguay               3/3/22    849050
#   12 │ Uzbekistan            3/3/22    236687
#   13 │ Vanuatu               3/3/22        19
#   14 │ Venezuela             3/3/22    515943
#   15 │ Vietnam               3/3/22   3885631
#   16 │ West Bank and Gaza    3/3/22    649110
#   17 │ Winter Olympics 2022  3/3/22       526
#   18 │ Yemen                 3/3/22     11772
#   19 │ Zambia                3/3/22    313394
#   20 │ Zimbabwe              3/3/22    237503

# %%
# convert de column “Date” from a categorical string format to a date format to plot time series.
df.Date = Dates.Date.(df.Date |> Array, Dates.DateFormat("m/d/Y")) .+ Dates.Year(2000)
# Out:
# 152658-element Vector{Date}:
#  2020-01-22
#  2020-01-22
#  2020-01-22
#  2020-01-22
#  2020-01-22
#  2020-01-22
#  2020-01-22
#  2020-01-22
#  2020-01-22
#  2020-01-22
#  2020-01-22
#  2020-01-22
#  2020-01-22
#  ⋮
#  2022-03-02
#  2022-03-02
#  2022-03-02
#  2022-03-02
#  2022-03-02
#  2022-03-02
#  2022-03-02
#  2022-03-02
#  2022-03-02
#  2022-03-02
#  2022-03-02
#  2022-03-02

# %%
describe(df)
# Out:
# 3×7 DataFrame
#  Row │ variable        mean       min          median      max         nmissin ⋯
#      │ Symbol          Union…     Any          Any         Any         Int64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Country/Region             Afghanistan              Zimbabwe            ⋯
#    2 │ Date                       2020-01-22   2021-02-10  2022-03-02
#    3 │ Cases           6.38636e5  0            19654.5     79143716
#                                                                2 columns omitted

# %%
CSV.write(joinpath(pwd(), "confirmed_tidy.csv"), df) # CSV aanmaken op pc
# Out:
# "/Users/casper/Desktop/Bachelorproef/confirmed_tidy.csv"

# %%
#Plotting the covid 19 cases of US

plot(
    df[df[!,"Country/Region"] .== "US", :Date],
    df[df[!,"Country/Region"] .== "US", :Cases],
    title = "Confirmed cases US",
    xlabel = "Date",
    ylabel = "Number of cases",
    legend = false,
)

# %%
# Different countries covid 19 cases

p = plot(
    title = "Confirmed Cases",
    xlabel = "Date",
    ylabel = "Number of cases",
    legend = :topleft,
)

for country = ["US", "Russia", "India"]
    plot!(
        df[df[!,"Country/Region"] .== country, :Date],
        df[df[!,"Country/Region"] .== country, :Cases],
        label = country,
    )
end

# %%
p

# %%
println(df[df[!,"Country/Region"] .== "US", :Date][1:3])
# Out:
# [Date("2020-01-22"), Date("2020-01-23"), Date("2020-01-24")]

# %%
#the daily new cases for the US. To do so, we have to calculate the differences between to successive days. 
#So, for the first day in the time series, this value will not be available.

bar(
    df[df[!,"Country/Region"] .== "US", :Date],
    diff(df[df[!,"Country/Region"] .== "US", :Cases]),
    title = "Daily Cases US",
    xlabel = "Date",
    ylabel = "Number of cases",
    color = "red",
    linecolor = "pink",
    legend = false,
    size = (1000, 400),
)
